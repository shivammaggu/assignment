# %%
#Question 1

import pandas as pd

df = pd.DataFrame({
    'name' : ['shivam','tarun','shantanu','ashutosh'],
    'age' : [21,21,22,22],
    'mail id' : ['shivammaggu1@gmail.com','skipperbhatt@gmail.com','mangalam.sms@gmail.com','ashuji0612@gmail.com'],
    'phone no' : ['9045777780','9412919681','9898567544','9997878242']
})
print("original dataframe :\n" ,df)

df2 = pd.DataFrame({'name' : ['naman'], 'age' : [22], 'mail id' : ['naman@.com'],'phone no' : ['9878787851']})
print("new information :\n" ,df2)

print("current dataframe :\n")
pd.concat([df,df2])
# Out:
# original dataframe :
#     age                 mail id      name    phone no
# 0   21  shivammaggu1@gmail.com    shivam  9045777780
# 1   21  skipperbhatt@gmail.com     tarun  9412919681
# 2   22  mangalam.sms@gmail.com  shantanu  9898567544
# 3   22    ashuji0612@gmail.com  ashutosh  9997878242
# new information :
#     age     mail id   name    phone no
# 0   22  naman@.com  naman  9878787851
# current dataframe :
#    age                 mail id      name    phone no
# 0   21  shivammaggu1@gmail.com    shivam  9045777780
# 1   21  skipperbhatt@gmail.com     tarun  9412919681
# 2   22  mangalam.sms@gmail.com  shantanu  9898567544
# 3   22    ashuji0612@gmail.com  ashutosh  9997878242
# 0   22              naman@.com     naman  9878787851

# %%
#Question 2

import pandas as pd

url ='https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv'
df = pd.read_csv(url)
print('first five rows of dataframe =\n')
df.head()
# Out:
# first five rows of dataframe =
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
print('first ten rows of dataframe =\n')
df.head(10)
# Out:
# first ten rows of dataframe =
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# ...

# %%
print('first basic statistics dataframe =\n')
df.describe(include = 'all')
# Out:
# first basic statistics dataframe =
#             Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count        366       366  366.000000  366.000000  366.000000   366.000000
# unique       366         1         NaN         NaN         NaN          NaN
# top     5/4/2008  Canberra         NaN         NaN         NaN          NaN
# freq           1       366         NaN         NaN         NaN          NaN
# mean         NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std          NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min          NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%          NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%          NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%          NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max          NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
print('last five rows of dataframe =\n')
df.tail()
# Out:
# last five rows of dataframe =
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
# ...

# %%
print('last ten rows of dataframe =\n')
df.tail(10)
# Out:
# last ten rows of dataframe =
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 356  10/22/2008  Canberra      3.4     15.0       0.8          4.8      11.7
# 357  10/23/2008  Canberra      3.2     18.0       0.0          7.4      12.2
# 358  10/24/2008  Canberra      0.9     20.7       0.0          5.4       8.4
# 359  10/25/2008  Canberra      3.3     25.5       0.0          5.2      10.8
# 360  10/26/2008  Canberra      7.9     26.1       0.0          6.8       3.5
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# ...
